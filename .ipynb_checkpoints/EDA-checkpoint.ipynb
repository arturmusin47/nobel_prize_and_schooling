# %%
import pandas as pd
import numpy as np
import tabula
import matplotlib.pyplot as plt
import random
import pycountry
import geopandas
# %matplotlib inline

# %%
#Number of Nobel prize winner vs schooling and GDP per capita by country
nobel=pd.read_csv('data/complete.csv')

# %%
nobel.fullName[nobel.fullName.notnull()]
# Out:
# 0                A. Michael Spence
# 1                  Aage Niels Bohr
# 2                Aaron Ciechanover
# 3                       Aaron Klug
# 4                      Abdus Salam
#                   ...
# 942              Zhores I. Alferov
# 943               Frederick Sanger
# 945                   John Bardeen
# 946             Linus Carl Pauling
# 947    Marie Curie, née Sklodowska
# Name: fullName, Length: 923, dtype: object

# %%
nobel.info()

# %%
nobel.category.unique()
# Out:
# array(['Economic Sciences', 'Physics', 'Chemistry', 'Peace',
#        'Physiology or Medicine', 'Literature'], dtype=object)

# %%
#Exclude category for Peace and Literature since we are working on science categories 
nobel_science_df=nobel[~((nobel.category=='Peace') | (nobel.category=='Literature'))]

# %%
nobel_science_df.category.unique()
# Out:
# array(['Economic Sciences', 'Physics', 'Chemistry',
#        'Physiology or Medicine'], dtype=object)

# %%
#filling Nan(s) with 'no_affiliation' for  affiliation columns
nobel_science_df['affiliation_1'] = nobel_science_df['affiliation_1'].fillna("no_affiliation")
nobel_science_df['affiliation_2'] = nobel_science_df['affiliation_2'].fillna("no_affiliation")
nobel_science_df['affiliation_3'] = nobel_science_df['affiliation_3'].fillna("no_affiliation")
nobel_science_df['affiliation_4'] = nobel_science_df['affiliation_4'].fillna("no_affiliation")
# Out:
# /home/artur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/artur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/artur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/artur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
nobel_science_df['country_of_affiliation_1']=nobel_science_df['affiliation_1'].apply(lambda x: x.split(',')[-1].strip())
nobel_science_df['country_of_affiliation_2']=nobel_science_df['affiliation_2'].apply(lambda x: x.split(',')[-1].strip())
nobel_science_df['country_of_affiliation_3']=nobel_science_df['affiliation_3'].apply(lambda x: x.split(',')[-1].strip())
nobel_science_df['country_of_affiliation_4']=nobel_science_df['affiliation_4'].apply(lambda x: x.split(',')[-1].strip())
# Out:
# /home/artur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/artur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/artur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/artur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
nobel_science_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 700 entries, 0 to 947
# Data columns (total 56 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   awardYear                   700 non-null    int64
#  1   category                    700 non-null    object
#  2   categoryFullName            700 non-null    object
#  3   sortOrder                   700 non-null    int64
#  4   portion                     700 non-null    object
#  5   prizeAmount                 700 non-null    int64
#  6   prizeAmountAdjusted         700 non-null    int64
#  7   dateAwarded                 372 non-null    object
#  8   prizeStatus                 700 non-null    object
#  9   motivation                  700 non-null    object
#  10  categoryTopMotivation       20 non-null     object
#  11  award_link                  700 non-null    object
#  12  id                          700 non-null    int64
#  13  name                        700 non-null    object
#  14  knownName                   700 non-null    object
#  15  givenName                   700 non-null    object
#  16  familyName                  700 non-null    object
#  17  fullName                    700 non-null    object
#  18  penName                     0 non-null      object
#  19  gender                      700 non-null    object
#  20  laureate_link               700 non-null    object
#  21  birth_date                  700 non-null    object
#  22  birth_city                  699 non-null    object
#  23  birth_cityNow               699 non-null    object
#  24  birth_continent             700 non-null    object
#  25  birth_country               700 non-null    object
#  26  birth_countryNow            700 non-null    object
#  27  birth_locationString        700 non-null    object
#  28  death_date                  456 non-null    object
#  29  death_city                  439 non-null    object
#  30  death_cityNow               439 non-null    object
#  31  death_continent             444 non-null    object
#  32  death_country               444 non-null    object
#  33  death_countryNow            444 non-null    object
#  34  death_locationString        445 non-null    object
#  35  orgName                     0 non-null      object
#  36  nativeName                  0 non-null      object
#  37  acronym                     0 non-null      object
#  38  org_founded_date            0 non-null      object
#  39  org_founded_city            0 non-null      object
#  40  org_founded_cityNow         0 non-null      object
#  41  org_founded_continent       0 non-null      object
#  42  org_founded_country         0 non-null      object
#  43  org_founded_countryNow      0 non-null      object
#  44  org_founded_locationString  0 non-null      object
#  45  ind_or_org                  700 non-null    object
#  46  residence_1                 5 non-null      object
#  47  residence_2                 0 non-null      object
#  48  affiliation_1               700 non-null    object
#  49  affiliation_2               700 non-null    object
#  50  affiliation_3               700 non-null    object
#  51  affiliation_4               700 non-null    object
#  52  country_of_affiliation_1    700 non-null    object
#  53  country_of_affiliation_2    700 non-null    object
#  54  country_of_affiliation_3    700 non-null    object
#  55  country_of_affiliation_4    700 non-null    object
# dtypes: int64(5), object(51)
# memory usage: 311.7+ KB

# %%
#Check residences 
nobel_science_df[['fullName','birth_country','birth_countryNow','death_country','death_countryNow','residence_1','residence_2','ind_or_org','country_of_affiliation_1','country_of_affiliation_2','country_of_affiliation_3','country_of_affiliation_4']][nobel_science_df.residence_1.notnull()]
# Out:
#                   fullName    birth_country birth_countryNow death_country  \
# 409        J. Robin Warren        Australia        Australia           NaN
# 505         Kary B. Mullis              USA              USA           USA
# 577  Martinus J.G. Veltman  the Netherlands  the Netherlands           NaN
# 899       Werner Forssmann          Germany          Germany  West Germany
# 921     William S. Knowles              USA              USA           USA
#
#     death_countryNow                 residence_1 residence_2  ind_or_org  \
# 409              NaN            Perth, Australia         NaN  Individual
# 505              USA           La Jolla, CA, USA         NaN  Individual
# 577              NaN  Bilthoven, the Netherlands         NaN  Individual
# 899          Germany      Bad Kreuznach, Germany         NaN  Individual
# 921              USA          St. Louis, MO, USA         NaN  Individual
#
#     country_of_affiliation_1 country_of_affiliation_2  \
# 409           no_affiliation           no_affiliation
# 505           no_affiliation           no_affiliation
# 577           no_affiliation           no_affiliation
# 899                  Germany           no_affiliation
# 921           no_affiliation           no_affiliation
#
#     country_of_affiliation_3 country_of_affiliation_4
# 409           no_affiliation           no_affiliation
# 505           no_affiliation           no_affiliation
# 577           no_affiliation           no_affiliation
# 899           no_affiliation           no_affiliation
# 921           no_affiliation           no_affiliation

# %%
#Check residence 
nobel_science_df[['fullName','birth_country','birth_countryNow','death_country','death_countryNow','residence_1','residence_2','ind_or_org','country_of_affiliation_1','country_of_affiliation_2','country_of_affiliation_3','country_of_affiliation_4']][nobel_science_df.residence_2.notnull()]
# Out:
# Empty DataFrame
# Columns: [fullName, birth_country, birth_countryNow, death_country, death_countryNow, residence_1, residence_2, ind_or_org, country_of_affiliation_1, country_of_affiliation_2, country_of_affiliation_3, country_of_affiliation_4]
# Index: []

# %%
#Check all pure science winners 
nobel_science_df[['fullName','birth_country','birth_countryNow','death_country','death_countryNow','country_of_affiliation_1','country_of_affiliation_2','country_of_affiliation_3','country_of_affiliation_4']]
# Out:
#                         fullName                      birth_country  \
# 0              A. Michael Spence                                USA
# 1                Aage Niels Bohr                            Denmark
# 2              Aaron Ciechanover  British Protectorate of Palestine
# 3                     Aaron Klug                          Lithuania
# 4                    Abdus Salam                              India
# ..                           ...                                ...
# 942            Zhores I. Alferov                               USSR
# 943             Frederick Sanger                     United Kingdom
# 945                 John Bardeen                                USA
# 946           Linus Carl Pauling                                USA
# 947  Marie Curie, née Sklodowska                     Russian Empire
#
#     birth_countryNow   death_country death_countryNow  \
# 0                USA             NaN              NaN
# 1            Denmark         Denmark          Denmark
# 2             Israel             NaN              NaN
# 3          Lithuania             NaN              NaN
# 4           Pakistan  United Kingdom   United Kingdom
# ..               ...             ...              ...
# 942          Belarus          Russia           Russia
# 943   United Kingdom  United Kingdom   United Kingdom
# 945              USA             USA              USA
# 946              USA             USA              USA
# 947           Poland          France           France
#
#     country_of_affiliation_1 country_of_affiliation_2  \
# 0                        USA           no_affiliation
# 1                    Denmark           no_affiliation
# 2                     Israel           no_affiliation
# 3             United Kingdom           no_affiliation
# 4                      Italy           United Kingdom
# ..                       ...                      ...
# 942                   Russia           no_affiliation
# 943           United Kingdom           no_affiliation
# 945                      USA           no_affiliation
# 946                      USA           no_affiliation
# 947                   France           no_affiliation
#
#     country_of_affiliation_3 country_of_affiliation_4
# 0             no_affiliation           no_affiliation
# 1             no_affiliation           no_affiliation
# 2             no_affiliation           no_affiliation
# 3             no_affiliation           no_affiliation
# 4             no_affiliation           no_affiliation
# ..                       ...                      ...
# 942           no_affiliation           no_affiliation
# 943           no_affiliation           no_affiliation
# 945           no_affiliation           no_affiliation
# 946           no_affiliation           no_affiliation
# 947           no_affiliation           no_affiliation
#
# [700 rows x 9 columns]

# %%
# check Birth country VS Death Country
nobel_science_df[['fullName','birth_country','country_of_affiliation_1','country_of_affiliation_2','country_of_affiliation_3','country_of_affiliation_4']][nobel_science_df['birth_countryNow']!=nobel_science_df['country_of_affiliation_1']]
# Out:
#                         fullName   birth_country country_of_affiliation_1  \
# 3                     Aaron Klug       Lithuania           United Kingdom
# 4                    Abdus Salam           India                    Italy
# 5               Abhijit Banerjee           India                      USA
# 13               Ahmed H. Zewail           Egypt                      USA
# 19            Alan G. MacDiarmid     New Zealand                      USA
# ..                           ...             ...                      ...
# 938               Yoichiro Nambu           Japan                      USA
# 940                  Yuan T. Lee          Taiwan                      USA
# 941                 Yves Chauvin         Belgium                   France
# 942            Zhores I. Alferov            USSR                   Russia
# 947  Marie Curie, née Sklodowska  Russian Empire                   France
#
#     country_of_affiliation_2 country_of_affiliation_3 country_of_affiliation_4
# 3             no_affiliation           no_affiliation           no_affiliation
# 4             United Kingdom           no_affiliation           no_affiliation
# 5             no_affiliation           no_affiliation           no_affiliation
# 13            no_affiliation           no_affiliation           no_affiliation
# 19            no_affiliation           no_affiliation           no_affiliation
# ..                       ...                      ...                      ...
# 938           no_affiliation           no_affiliation           no_affiliation
# 940           no_affiliation           no_affiliation           no_affiliation
# 941           no_affiliation           no_affiliation           no_affiliation
# 942           no_affiliation           no_affiliation           no_affiliation
# 947           no_affiliation           no_affiliation           no_affiliation
#
# [237 rows x 6 columns]

# %%
# check 10 random winners whose Birth Country differs from Counrty of Affiliation for schooling counnrty  
cadidates_for_random=np.array(nobel_science_df[['fullName']][nobel_science_df['birth_countryNow']!=nobel_science_df['country_of_affiliation_1']])
cadidates_for_random
random.choices(cadidates_for_random, k=20)
# Out:
# [array(['Guglielmo Marconi'], dtype=object),
#  array(['Richard Henderson'], dtype=object),
#  array(['J. Robin Warren'], dtype=object),
#  array(['William S. Knowles'], dtype=object),
#  array(['Friedrich Bergius'], dtype=object),
#  array(['Georg von Békésy'], dtype=object),
#  array(['Tadeus Reichstein'], dtype=object),
#  array(['Polykarp Kusch'], dtype=object),
#  array(['Torsten N. Wiesel'], dtype=object),
#  array(['Konstantin Novoselov'], dtype=object),
#  array(['Hans Karl August Simon von Euler-Chelpin'], dtype=object),
#  array(['Amartya Sen'], dtype=object),
#  array(['Otto Wallach'], dtype=object),
#  array(['Georges J.F. Köhler'], dtype=object),
#  array(['Maurice Hugh Frederick Wilkins'], dtype=object),
#  array(['Martinus J.G. Veltman'], dtype=object),
#  array(['Peter Grünberg'], dtype=object),
#  array(['Salvador E. Luria'], dtype=object),
#  array(['Richard Adolf Zsigmondy'], dtype=object),
#  array(['Peter Brian Medawar'], dtype=object)]

# %%
#Decided to move with Birth Counrty as final feature field to pursue analysis against other scholling data set
#final columns need
nobel_science_final=nobel_science_df[['fullName', 'birth_countryNow']]
nobel_science_final
# Out:
#                         fullName birth_countryNow
# 0              A. Michael Spence              USA
# 1                Aage Niels Bohr          Denmark
# 2              Aaron Ciechanover           Israel
# 3                     Aaron Klug        Lithuania
# 4                    Abdus Salam         Pakistan
# ..                           ...              ...
# 942            Zhores I. Alferov          Belarus
# 943             Frederick Sanger   United Kingdom
# 945                 John Bardeen              USA
# 946           Linus Carl Pauling              USA
# 947  Marie Curie, née Sklodowska           Poland
#
# [700 rows x 2 columns]

# %%
grouped_nobel=nobel_science_final.groupby('birth_countryNow').count()
grouped_nobel['birth_countryNow']=grouped_nobel.index
grouped_nobel
# Out:
#                          fullName         birth_countryNow
# birth_countryNow
# Algeria                         1                  Algeria
# Argentina                       2                Argentina
# Australia                      10                Australia
# Austria                        15                  Austria
# Azerbaijan                      1               Azerbaijan
# Belarus                         2                  Belarus
# Belgium                         5                  Belgium
# Bosnia and Herzegovina          1   Bosnia and Herzegovina
# Brazil                          1                   Brazil
# Canada                         17                   Canada
# China                           8                    China
# Croatia                         1                  Croatia
# Cyprus                          1                   Cyprus
# Czech Republic                  4           Czech Republic
# Denmark                         6                  Denmark
# Egypt                           2                    Egypt
# Faroe Islands (Denmark)         1  Faroe Islands (Denmark)
# Finland                         3                  Finland
# France                         35                   France
# Germany                        70                  Germany
# Hungary                         8                  Hungary
# India                           6                    India
# Indonesia                       1                Indonesia
# Ireland                         2                  Ireland
# Israel                          5                   Israel
# Italy                          12                    Italy
# Japan                          23                    Japan
# Latvia                          1                   Latvia
# Lithuania                       2                Lithuania
# Luxembourg                      2               Luxembourg
# Mexico                          1                   Mexico
# Morocco                         1                  Morocco
# New Zealand                     3              New Zealand
# Norway                          8                   Norway
# Pakistan                        2                 Pakistan
# Poland                         19                   Poland
# Portugal                        1                 Portugal
# Romania                         2                  Romania
# Russia                         19                   Russia
# Saint Lucia                     1              Saint Lucia
# Scotland                        9                 Scotland
# Slovakia                        1                 Slovakia
# Slovenia                        1                 Slovenia
# South Africa                    4             South Africa
# South Korea                     1              South Korea
# Spain                           2                    Spain
# Sweden                         17                   Sweden
# Switzerland                    15              Switzerland
# Taiwan                          1                   Taiwan
# Turkey                          1                   Turkey
# USA                           246                      USA
# Ukraine                         3                  Ukraine
# United Kingdom                 76           United Kingdom
# Venezuela                       1                Venezuela
# the Netherlands                17          the Netherlands

# %%
nobel_science_final.birth_countryNow.unique()
# Out:
# array(['USA', 'Denmark', 'Israel', 'Lithuania', 'Pakistan', 'India',
#        'Germany', 'Egypt', 'Japan', 'United Kingdom', 'New Zealand',
#        'Poland', 'Belgium', 'France', 'Hungary', 'Australia', 'Russia',
#        'South Africa', 'Sweden', 'Scotland', 'Canada', 'Finland',
#        'Turkey', 'Venezuela', 'the Netherlands', 'Argentina', 'Italy',
#        'Czech Republic', 'Switzerland', 'South Korea', 'China', 'Cyprus',
#        'Algeria', 'Norway', 'Portugal', 'Austria', 'Ireland', 'Slovenia',
#        'Luxembourg', 'Romania', 'Ukraine', 'Croatia', 'Azerbaijan',
#        'Mexico', 'Faroe Islands (Denmark)', 'Brazil', 'Slovakia', 'Spain',
#        'Morocco', 'Belarus', 'Saint Lucia', 'Bosnia and Herzegovina',
#        'Latvia', 'Indonesia', 'Taiwan'], dtype=object)

# %%
# generate country code  based on country name 
def alpha3code(column):
    CODE=[]
    for country in column:
        try:
            if country=='Faroe Islands (Denmark)':
                country='Denmark'
            if country=='South Korea':
                country='Korea, Republic of'
            else:
                code=pycountry.countries.search_fuzzy(country)[0].alpha_3

           # .alpha_3 means 3-letter country code 
           # .alpha_2 means 2-letter country code
            CODE.append(code)
        except:
            CODE.append('None')
            
    return CODE# create a column for code 
grouped_nobel['CODE']=alpha3code(grouped_nobel.birth_countryNow)
grouped_nobel
grouped_nobel.rename(columns={'fullName': 'count_of_winners'}, inplace=True)
grouped_nobel
# Out:
#                          count_of_winners         birth_countryNow CODE
# birth_countryNow
# Algeria                                 1                  Algeria  DZA
# Argentina                               2                Argentina  ARG
# Australia                              10                Australia  AUS
# Austria                                15                  Austria  AUT
# Azerbaijan                              1               Azerbaijan  AZE
# Belarus                                 2                  Belarus  BLR
# Belgium                                 5                  Belgium  BEL
# Bosnia and Herzegovina                  1   Bosnia and Herzegovina  BIH
# Brazil                                  1                   Brazil  BRA
# Canada                                 17                   Canada  CAN
# China                                   8                    China  CHN
# Croatia                                 1                  Croatia  HRV
# Cyprus                                  1                   Cyprus  CYP
# Czech Republic                          4           Czech Republic  CZE
# Denmark                                 6                  Denmark  DNK
# Egypt                                   2                    Egypt  EGY
# Faroe Islands (Denmark)                 1  Faroe Islands (Denmark)  DNK
# Finland                                 3                  Finland  FIN
# France                                 35                   France  FRA
# Germany                                70                  Germany  DEU
# Hungary                                 8                  Hungary  HUN
# India                                   6                    India  IND
# Indonesia                               1                Indonesia  IDN
# Ireland                                 2                  Ireland  IRL
# Israel                                  5                   Israel  ISR
# Italy                                  12                    Italy  ITA
# Japan                                  23                    Japan  JPN
# Latvia                                  1                   Latvia  LVA
# Lithuania                               2                Lithuania  LTU
# Luxembourg                              2               Luxembourg  LUX
# Mexico                                  1                   Mexico  MEX
# Morocco                                 1                  Morocco  MAR
# New Zealand                             3              New Zealand  NZL
# Norway                                  8                   Norway  NOR
# Pakistan                                2                 Pakistan  PAK
# Poland                                 19                   Poland  POL
# Portugal                                1                 Portugal  PRT
# Romania                                 2                  Romania  ROU
# Russia                                 19                   Russia  RUS
# Saint Lucia                             1              Saint Lucia  LCA
# Scotland                                9                 Scotland  GBR
# Slovakia                                1                 Slovakia  SVK
# Slovenia                                1                 Slovenia  SVN
# South Africa                            4             South Africa  ZAF
# South Korea                             1              South Korea  ZAF
# Spain                                   2                    Spain  ESP
# Sweden                                 17                   Sweden  SWE
# Switzerland                            15              Switzerland  CHE
# Taiwan                                  1                   Taiwan  TWN
# Turkey                                  1                   Turkey  TUR
# USA                                   246                      USA  USA
# Ukraine                                 3                  Ukraine  UKR
# United Kingdom                         76           United Kingdom  GBR
# Venezuela                               1                Venezuela  VEN
# the Netherlands                        17          the Netherlands  NLD

# %%
# first let us merge geopandas data with our data
# 'naturalearth_lowres' is geopandas datasets so we can use it directly
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))# rename the columns so that we can merge with our data
world.columns=['pop_est', 'continent', 'name', 'CODE', 'gdp_md_est', 'geometry']# then merge with our data 
merge=pd.merge(world,grouped_nobel,on='CODE')# last thing we need to do is - merge again with our location data which contains each country’s latitude and longitude
location=pd.read_csv('https://raw.githubusercontent.com/melanieshi0120/COVID-19_global_time_series_panel_data/master/data/countries_latitude_longitude.csv')
merge=merge.merge(location,on='name').sort_values(by='count_of_winners',ascending=False).reset_index()

# %%
# plot confirmed cases world map 
merge.plot(column='count_of_winners', scheme="quantiles",
           figsize=(25, 20),
           legend=True,cmap='PiYG')
plt.title('Number of Nobel winners by country in pure science categories',fontsize=25)# add countries names and numbers 
for i in range(0,10):
    try:
        plt.text(float(merge.longitude[i]),float(merge.latitude[i]),"{}\n{}".format(merge.name[i],merge.count_of_winners[i]),size=10)
    except:
        pass
plt.savefig('Number of Nobel winners by country in pure science categories.png')
# plt.show()

# %%
top_20_countries=merge[:20]

# %%
top_20_countries.plot(x='birth_countryNow',y='count_of_winners',kind='barh', colormap='Set1', figsize=(20,10), title='Top 20 Countries with Nobel winners in pure science')
plt.savefig('Top 20 Countries with Nobel winners in pure science.png')

# %%
#plot grouped countries per number of winner from those countries 

plt.style.use('ggplot')
# x = ['Macron', 'Le Pen']
# tweets = [res_lepen.count(), res_macron.count()]
plt.figure(figsize=(30,7))
x_pos = [i for i, _ in enumerate(most_common_words)]
plt.hist(top_20_city)
plt.xlabel("City")
plt.ylabel("Number of tweets associated")
plt.title("Number of tweets associated per city for Macron")
plt.xticks(x_pos, most_common_words)
plt.tight_layout()
# plt.show()

# %%
# Calculate mean age of winner at time of award
nobel_science_age=nobel_science_df[['awardYear','birth_date','fullName', 'birth_countryNow']]
nobel_science_age['birth_year']=nobel_science_age['birth_date'].str.slice(start=0,stop=4)
nobel_science_age['birth_year']=nobel_science_age['birth_year'].astype('int64')

nobel_science_age['Age of winner at the award time']=nobel_science_age['awardYear']-nobel_science_age['birth_year']

# grouped_nobel=nobel_science_final.groupby('birth_countryNow').count()
# grouped_nobel['birth_countryNow']=grouped_nobel.index
# grouped_nobel

nobel_science_age
# Out:
# /home/artur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/artur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/artur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      awardYear  birth_date                     fullName birth_countryNow  \
# 0         2001  1943-00-00            A. Michael Spence              USA
# 1         1975  1922-06-19              Aage Niels Bohr          Denmark
# 2         2004  1947-10-01            Aaron Ciechanover           Israel
# 3         1982  1926-08-11                   Aaron Klug        Lithuania
# 4         1979  1926-01-29                  Abdus Salam         Pakistan
# ..         ...         ...                          ...              ...
# 942       2000  1930-03-15            Zhores I. Alferov          Belarus
# 943       1980  1918-08-13             Frederick Sanger   United Kingdom
# 945       1972  1908-05-23                 John Bardeen              USA
# 946       1954  1901-02-28           Linus Carl Pauling              USA
# 947       1911  1867-11-07  Marie Curie, née Sklodowska           Poland
#
#      birth_year  Age of winner at the award time
# 0          1943                               58
# 1          1922                               53
# 2          1947                               57
# 3          1926                               56
# 4          1926                               53
# ..          ...                              ...
# 942        1930                               70
# 943        1918                               62
# 945        1908                               64
# 946        1901                               53
# 947        1867                               44
#
# [700 rows x 6 columns]

# %%
nobel_science_age_mean=nobel_science_age[['Age of winner at the award time','fullName']]
grouped_age_mean=nobel_science_age_mean.groupby('Age of winner at the award time').count()
grouped_age_mean['Age of winner at the award time']=grouped_age.index
grouped_age_mean.sort_index(inplace=True)
grouped_age_mean.plot(x='Age of winner at the award time',y='fullName',kind='bar', legend=False, ylabel='Winner count',colormap='coolwarm', figsize=(20,10), title='Average age of Nobel winners in pure science')
plt.savefig('Average age of Nobel winners in pure science.png')

# %%
#find mean age of award winner
np.mean(nobel_science_age['Age of winner at the award time'])
# Out:
# 58.85142857142857

# %%
#Determine school start year for each winner and assume that starting age for start schooling is 6 (average)
avg_schoool_start_age=6
nobel_science_age['Year of schooling start of winner']=nobel_science_age['birth_year']+avg_schoool_start_age
nobel_science_age
# Out:
# /home/artur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      awardYear  birth_date                     fullName birth_countryNow  \
# 0         2001  1943-00-00            A. Michael Spence              USA
# 1         1975  1922-06-19              Aage Niels Bohr          Denmark
# 2         2004  1947-10-01            Aaron Ciechanover           Israel
# 3         1982  1926-08-11                   Aaron Klug        Lithuania
# 4         1979  1926-01-29                  Abdus Salam         Pakistan
# ..         ...         ...                          ...              ...
# 942       2000  1930-03-15            Zhores I. Alferov          Belarus
# 943       1980  1918-08-13             Frederick Sanger   United Kingdom
# 945       1972  1908-05-23                 John Bardeen              USA
# 946       1954  1901-02-28           Linus Carl Pauling              USA
# 947       1911  1867-11-07  Marie Curie, née Sklodowska           Poland
#
#      birth_year  Age of winner at the award time  \
# 0          1943                               58
# 1          1922                               53
# 2          1947                               57
# 3          1926                               56
# 4          1926                               53
# ..          ...                              ...
# 942        1930                               70
# 943        1918                               62
# 945        1908                               64
# 946        1901                               53
# 947        1867                               44
#
#      Year of schooling start of winner
# 0                                 1949
# 1                                 1928
# 2                                 1953
# 3                                 1932
# 4                                 1932
# ..                                 ...
# 942                               1936
# 943                               1924
# 945                               1914
# 946                               1907
# 947                               1873
#
# [700 rows x 7 columns]

# %%
#Merge with CODE nobel_science_age and grouped_nobel
grouped_nobel.reset_index(drop=True, inplace=True)
merged_for_code=nobel_science_age.merge(grouped_nobel, how='left', on='birth_countryNow')
merged_for_code
# Out:
#      awardYear  birth_date                     fullName birth_countryNow  \
# 0         2001  1943-00-00            A. Michael Spence              USA
# 1         1975  1922-06-19              Aage Niels Bohr          Denmark
# 2         2004  1947-10-01            Aaron Ciechanover           Israel
# 3         1982  1926-08-11                   Aaron Klug        Lithuania
# 4         1979  1926-01-29                  Abdus Salam         Pakistan
# ..         ...         ...                          ...              ...
# 695       2000  1930-03-15            Zhores I. Alferov          Belarus
# 696       1980  1918-08-13             Frederick Sanger   United Kingdom
# 697       1972  1908-05-23                 John Bardeen              USA
# 698       1954  1901-02-28           Linus Carl Pauling              USA
# 699       1911  1867-11-07  Marie Curie, née Sklodowska           Poland
#
#      birth_year  Age of winner at the award time  \
# 0          1943                               58
# 1          1922                               53
# 2          1947                               57
# 3          1926                               56
# 4          1926                               53
# ..          ...                              ...
# 695        1930                               70
# 696        1918                               62
# 697        1908                               64
# 698        1901                               53
# 699        1867                               44
#
#      Year of schooling start of winner  count_of_winners CODE
# 0                                 1949               246  USA
# 1                                 1928                 6  DNK
# 2                                 1953                 5  ISR
# 3                                 1932                 2  LTU
# 4                                 1932                 2  PAK
# ..                                 ...               ...  ...
# 695                               1936                 2  BLR
# 696                               1924                76  GBR
# 697                               1914               246  USA
# 698                               1907               246  USA
# 699                               1873                19  POL
#
# [700 rows x 9 columns]

# %%
gdp_schooling=pd.read_csv('data/correlation-between-mean-years-of-schooling-and-gdp-per-capita.csv')
# Out:
#   File "<ipython-input-550-40547cd4c2f2>", line 1
#     gdp_schooling=pd.read_csv('data/correlation-between-mean-years-of-schooling-and-gdp-per-capita.csv').astype({'Total population (Gapminder, HYDE & UN)':'int'}
#                                                                                                                                                                  ^
# SyntaxError: unexpected EOF while parsing

# %%
len(gdp_schooling.Entity.unique())
# Out:
# 293

# %%
gdp_schooling.head()
# Out:
#         Entity      Code  Year  \
# 0     Abkhazia  OWID_ABK  2015
# 1  Afghanistan       AFG  1870
# 2  Afghanistan       AFG  1875
# 3  Afghanistan       AFG  1880
# 4  Afghanistan       AFG  1885
#
#    Output-side real GDP per capita (gdppc_o) (PWT 9.1 (2019))  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Total years of schooling (Lee-Lee (2016))  \
# 0                                        NaN
# 1                                       0.01
# 2                                       0.01
# 3                                       0.01
# 4                                       0.01
#
#    Total population (Gapminder, HYDE & UN) Continent
# 0                                      NaN      Asia
# 1                                4169690.0       NaN
# 2                                4285744.0       NaN
# 3                                4419695.0       NaN
# 4                                4562304.0       NaN

# %%
gdp_schooling_US=gdp_schooling[(gdp_schooling.CODE=='USA') & (gdp_schooling['Total years of schooling (Lee-Lee (2016))'].notnull())].sort_values(by='Year')

# %%
gdp_schooling_US
# Out:
#               Entity CODE  Year  \
# 44449  United States  USA  1870
# 44450  United States  USA  1875
# 44451  United States  USA  1880
# 44452  United States  USA  1885
# 44453  United States  USA  1890
# 44454  United States  USA  1895
# 44455  United States  USA  1900
# 44456  United States  USA  1905
# 44457  United States  USA  1910
# 44458  United States  USA  1915
# 44459  United States  USA  1920
# 44460  United States  USA  1925
# 44461  United States  USA  1930
# 44462  United States  USA  1935
# 44463  United States  USA  1940
# 44464  United States  USA  1945
# 44381  United States  USA  1950
# 44386  United States  USA  1955
# 44391  United States  USA  1960
# 44396  United States  USA  1965
# 44401  United States  USA  1970
# 44406  United States  USA  1975
# 44411  United States  USA  1980
# 44416  United States  USA  1985
# 44421  United States  USA  1990
# 44426  United States  USA  1995
# 44431  United States  USA  2000
# 44436  United States  USA  2005
# 44441  United States  USA  2010
#
#        Output-side real GDP per capita (gdppc_o) (PWT 9.1 (2019))  \
# 44449                                                NaN
# 44450                                                NaN
# 44451                                                NaN
# 44452                                                NaN
# 44453                                                NaN
# 44454                                                NaN
# 44455                                                NaN
# 44456                                                NaN
# 44457                                                NaN
# 44458                                                NaN
# 44459                                                NaN
# 44460                                                NaN
# 44461                                                NaN
# 44462                                                NaN
# 44463                                                NaN
# 44464                                                NaN
# 44381                                          14569.096
# 44386                                          16666.355
# 44391                                          17462.627
# 44396                                          20839.193
# 44401                                          23285.578
# 44406                                          25368.428
# 44411                                          29154.891
# 44416                                          32498.301
# 44421                                          36222.453
# 44426                                          39214.816
# 44431                                          45859.246
# 44436                                          49471.516
# 44441                                          49500.629
#
#        Total years of schooling (Lee-Lee (2016))  \
# 44449                                       4.28
# 44450                                       4.60
# 44451                                       4.91
# 44452                                       5.18
# 44453                                       5.55
# 44454                                       5.93
# 44455                                       6.38
# 44456                                       6.72
# 44457                                       6.76
# 44458                                       6.97
# 44459                                       7.20
# 44460                                       7.56
# 44461                                       7.90
# 44462                                       8.34
# 44463                                       8.68
# 44464                                       8.93
# 44381                                       8.74
# 44386                                       9.14
# 44391                                       9.63
# 44396                                      10.42
# 44401                                      11.10
# 44406                                      11.73
# 44411                                      12.28
# 44416                                      12.35
# 44421                                      12.55
# 44426                                      12.83
# 44431                                      13.10
# 44436                                      13.01
# 44441                                      13.24
#
#        Total population (Gapminder, HYDE & UN) Continent
# 44449                               40899168.0       NaN
# 44450                               45854328.0       NaN
# 44451                               51402380.0       NaN
# 44452                               57461504.0       NaN
# 44453                               64051772.0       NaN
# 44454                               70738200.0       NaN
# 44455                               77781472.0       NaN
# 44456                               85524304.0       NaN
# 44457                               94088792.0       NaN
# 44458                              102789832.0       NaN
# 44459                              109122856.0       NaN
# 44460                              118421720.0       NaN
# 44461                              125841184.0       NaN
# 44462                              130246608.0       NaN
# 44463                              135198128.0       NaN
# 44464                              143095072.0       NaN
# 44381                              158804000.0       NaN
# 44386                              171684992.0       NaN
# 44391                              186720992.0       NaN
# 44396                              199734000.0       NaN
# 44401                              209512992.0       NaN
# 44406                              219080992.0       NaN
# 44411                              229476000.0       NaN
# 44416                              240500000.0       NaN
# 44421                              252120000.0       NaN
# 44426                              265164000.0       NaN
# 44431                              281711008.0       NaN
# 44436                              294993984.0       NaN
# 44441                              309011008.0       NaN

# %%
#MERGE with Schooling dataset to add Total years of schooling to Nobel data set per year of start school and Country Code
gdp_schooling.rename(columns={'Code': 'CODE'}, inplace=True)
# merged_for_schoolling=merged_for_code.merge(gdp_schooling, how='left', left_on=['CODE','Year of schooling start of winner'], right_on=['CODE','Year'])

# %%
#outer merge to fullfill Nans for Total years of schooling (Lee-Lee (2016)) because Year out of range from schooling stats
merged_for_schoolling_outter=merged_for_code.merge(gdp_schooling, how='outer', left_on=['CODE','Year of schooling start of winner'], right_on=['CODE','Year'])

# %%
#Sorting by CODE and YEar
merged_for_schoolling_outter.sort_values(by=['CODE', 'Year'], inplace=True)

# %%
#fill Nans with prev record 
# merged_for_schoolling_outter['Total years of schooling (Lee-Lee (2016))'].ffill(inplace=True)
merged_for_schoolling_outter['Total years of schooling (Lee-Lee (2016))'][(merged_for_schoolling_outter.CODE=='USA')].fillna(method='bfill', inplace=True)
merged_for_schoolling_outter['Total years of schooling (Lee-Lee (2016))'][(merged_for_schoolling_outter.CODE=='USA')]
# Out:
# 44744   NaN
# 44745   NaN
# 44746   NaN
# 44747   NaN
# 44748   NaN
#          ..
# 44736   NaN
# 44737   NaN
# 44738   NaN
# 44828   NaN
# 44829   NaN
# Name: Total years of schooling (Lee-Lee (2016)), Length: 386, dtype: float64

# %%
final_df=merged_for_schoolling_outter[(merged_for_schoolling_outter['fullName'].notnull())]

# %%
final_df.sort_values(by=['CODE', 'Year'], inplace=True)
final_df
# Out:
# /home/artur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      awardYear  birth_date                     fullName birth_countryNow  \
# 132     1947.0  1887-04-10     Bernardo Alberto Houssay        Argentina
# 161     1984.0  1927-10-08               César Milstein        Argentina
# 520     1915.0  1890-03-31       William Lawrence Bragg        Australia
# 641     1945.0  1898-09-24     Sir Howard Walter Florey        Australia
# 637     1960.0  1899-09-03  Sir Frank Macfarlane Burnet        Australia
# ..         ...         ...                          ...              ...
# 546     1951.0  1899-01-30                  Max Theiler     South Africa
# 174     1987.0  1904-10-03          Charles J. Pedersen      South Korea
# 57      1979.0  1924-02-23             Allan M. Cormack     South Africa
# 654     2002.0  1927-01-13               Sydney Brenner     South Africa
# 549     2013.0  1947-05-09               Michael Levitt     South Africa
#
#      birth_year  Age of winner at the award time  \
# 132      1887.0                             60.0
# 161      1927.0                             57.0
# 520      1890.0                             25.0
# 641      1898.0                             47.0
# 637      1899.0                             61.0
# ..          ...                              ...
# 546      1899.0                             52.0
# 174      1904.0                             83.0
# 57       1924.0                             55.0
# 654      1927.0                             75.0
# 549      1947.0                             66.0
#
#      Year of schooling start of winner  count_of_winners CODE        Entity  \
# 132                             1893.0               2.0  ARG     Argentina
# 161                             1933.0               2.0  ARG     Argentina
# 520                             1896.0              10.0  AUS     Australia
# 641                             1904.0              10.0  AUS     Australia
# 637                             1905.0              10.0  AUS     Australia
# ..                                 ...               ...  ...           ...
# 546                             1905.0               4.0  ZAF  South Africa
# 174                             1910.0               1.0  ZAF  South Africa
# 57                              1930.0               4.0  ZAF  South Africa
# 654                             1933.0               4.0  ZAF  South Africa
# 549                             1953.0               4.0  ZAF  South Africa
#
#      Year  Output-side real GDP per capita (gdppc_o) (PWT 9.1 (2019))  \
# 132  1893                                                NaN
# 161  1933                                                NaN
# 520  1896                                                NaN
# 641  1904                                                NaN
# 637  1905                                                NaN
# ..    ...                                                ...
# 546  1905                                                NaN
# 174  1910                                                NaN
# 57   1930                                                NaN
# 654  1933                                                NaN
# 549  1953                                          5189.3135
#
#      Total years of schooling (Lee-Lee (2016))  \
# 132                                        NaN
# 161                                        NaN
# 520                                        NaN
# 641                                        NaN
# 637                                       3.36
# ..                                         ...
# 546                                       1.24
# 174                                       1.28
# 57                                        3.09
# 654                                        NaN
# 549                                        NaN
#
#      Total population (Gapminder, HYDE & UN) Continent
# 132                                3750784.0       NaN
# 161                               12633735.0       NaN
# 520                                3516129.0       NaN
# 641                                3962416.0       NaN
# 637                                4022248.0       NaN
# ..                                       ...       ...
# 546                                5209951.0       NaN
# 174                                5765058.0       NaN
# 57                                 8844999.0       NaN
# 654                                9437153.0       NaN
# 549                               14542000.0       NaN
#
# [700 rows x 15 columns]

# %%
final_df[final_df.CODE=='GBR']
# Out:
#      awardYear  birth_date                             fullName  \
# 525     1904.0  1842-11-12  Lord Rayleigh (John William Strutt)
# 648     1904.0  1852-10-02                   Sir William Ramsay
# 444     1906.0  1856-12-18                  Joseph John Thomson
# 636     1932.0  1857-11-27        Sir Charles Scott Sherrington
# 638     1929.0  1861-06-20        Sir Frederick Gowland Hopkins
# ..         ...         ...                                  ...
# 646     2001.0  1949-01-25                    Sir Paul M. Nurse
# 310     2016.0  1951-09-14                 F. Duncan M. Haldane
# 311     2018.0  1951-04-14                Sir Gregory P. Winter
# 446     2009.0  1952-11-09                      Jack W. Szostak
# 647     2019.0  1954-05-14               Sir Peter J. Ratcliffe
#
#     birth_countryNow  birth_year  Age of winner at the award time  \
# 525   United Kingdom      1842.0                             62.0
# 648         Scotland      1852.0                             52.0
# 444   United Kingdom      1856.0                             50.0
# 636   United Kingdom      1857.0                             75.0
# 638   United Kingdom      1861.0                             68.0
# ..               ...         ...                              ...
# 646   United Kingdom      1949.0                             52.0
# 310   United Kingdom      1951.0                             65.0
# 311   United Kingdom      1951.0                             67.0
# 446   United Kingdom      1952.0                             57.0
# 647   United Kingdom      1954.0                             65.0
#
#      Year of schooling start of winner  count_of_winners CODE          Entity  \
# 525                             1848.0              76.0  GBR  United Kingdom
# 648                             1858.0               9.0  GBR  United Kingdom
# 444                             1862.0              76.0  GBR  United Kingdom
# 636                             1863.0              76.0  GBR  United Kingdom
# 638                             1867.0              76.0  GBR  United Kingdom
# ..                                 ...               ...  ...             ...
# 646                             1955.0              76.0  GBR  United Kingdom
# 310                             1957.0              76.0  GBR  United Kingdom
# 311                             1957.0              76.0  GBR  United Kingdom
# 446                             1958.0              76.0  GBR  United Kingdom
# 647                             1960.0              76.0  GBR  United Kingdom
#
#      Year  Output-side real GDP per capita (gdppc_o) (PWT 9.1 (2019))  \
# 525  1848                                                NaN
# 648  1858                                                NaN
# 444  1862                                                NaN
# 636  1863                                                NaN
# 638  1867                                                NaN
# ..    ...                                                ...
# 646  1955                                          10766.068
# 310  1957                                          11114.774
# 311  1957                                          11114.774
# 446  1958                                          11110.438
# 647  1960                                          11909.774
#
#      Total years of schooling (Lee-Lee (2016))  \
# 525                                        NaN
# 648                                        NaN
# 444                                        NaN
# 636                                        NaN
# 638                                        NaN
# ..                                         ...
# 646                                       6.73
# 310                                        NaN
# 311                                        NaN
# 446                                        NaN
# 647                                       7.01
#
#      Total population (Gapminder, HYDE & UN) Continent
# 525                               22228262.0       NaN
# 648                               24292422.0       NaN
# 444                               25323118.0       NaN
# 636                               25601036.0       NaN
# 638                               26746068.0       NaN
# ..                                       ...       ...
# 646                               51064000.0       NaN
# 310                               51496000.0       NaN
# 311                               51496000.0       NaN
# 446                               51755000.0       NaN
# 647                               52371000.0       NaN
#
# [85 rows x 15 columns]

# %%
#USA data filter for Correlation
max_year_US=merged_for_code['Year of schooling start of winner'][merged_for_code.CODE=='USA'].max()
min_year_US=merged_for_code['Year of schooling start of winner'][merged_for_code.CODE=='USA'].min()
min_year_US, max_year_US

# %%
final_school_df_USA=gdp_schooling_US[(gdp_schooling_US.Year>=min_year_US) & (gdp_schooling_US.Year<=max_year_US)].sort_values(by='Year')

# %%
winner_count_by_year=merged_for_code[merged_for_code.CODE=='USA'].groupby('Year of schooling start of winner').count()['fullName']

# %%
#Correlation between number of schooling years and number of nobel prize winners for given year for USA
winner_count_by_year
fig, ax = plt.subplots(figsize=(15,10))
plt.plot(final_school_df_USA.Year, final_school_df_USA['Total years of schooling (Lee-Lee (2016))'], color='red')
plt.bar(winner_count_by_year.index, winner_count_by_year)

plt.title('Correlation between number of schooling years and number of nobel prize winners for given year for USA',fontsize=15)
ax.set_xlabel('Year',fontsize=15)
ax.set_ylabel('Number of school years and number of winners',fontsize=15)
fig.legend(labels = ('schooling years','winner_count_by_year'), loc='upper right')


plt.savefig('Correlation between schooling and winners USA.png')

# %%
#GBR data filter for Correlation
gdp_schooling_UK=gdp_schooling[(gdp_schooling.CODE=='GBR') & (gdp_schooling['Total years of schooling (Lee-Lee (2016))'].notnull())].sort_values(by='Year')
max_year_UK=merged_for_code['Year of schooling start of winner'][merged_for_code.CODE=='GBR'].max()
min_year_UK=merged_for_code['Year of schooling start of winner'][merged_for_code.CODE=='GBR'].min()
min_year_UK, max_year_UK
final_school_df_UK=gdp_schooling_UK[(gdp_schooling_UK.Year>=min_year_UK) & (gdp_schooling_UK.Year<=max_year_UK)].sort_values(by='Year')
# merged_for_code

winner_count_by_year_UK=merged_for_code[merged_for_code.CODE=='GBR'].groupby('Year of schooling start of winner').count()['fullName']

# %%
#Correlation between number of schooling years and number of nobel prize winners for given year for UK
fig, ax = plt.subplots(figsize=(15,10))
plt.plot(final_school_df_UK.Year, final_school_df_UK['Total years of schooling (Lee-Lee (2016))'], color='red')
plt.bar(winner_count_by_year_UK.index, winner_count_by_year_UK, color='green')

plt.title('Correlation between number of schooling years and number of nobel prize winners for given year for UK',fontsize=15)
ax.set_xlabel('Year',fontsize=15)
ax.set_ylabel('Number of school years and number of winners',fontsize=15)
fig.legend(labels = ('schooling years','winner_count_by_year'), loc='upper right')

# plt.show()
plt.savefig('Correlation between schooling and winners UK.png')

# %%
#create array of birth year of winners to find min and max find population means for those years
birth_years=np.array(nobel['birth_date'][nobel.fullName.notnull()].str.slice(start=0,stop=4).dropna())

# Filtering Entity=United States and year range(min(birth_years), max(birth_years))
mean_USA_population=np.mean(gdp_schooling['Total population (Gapminder, HYDE & UN)'][(gdp_schooling.Entity=='United States') & (gdp_schooling.Year>=int(np.min(birth_years))) & (gdp_schooling.Year<=int(np.max(birth_years)))].dropna().astype('int64'))
# Filtering Entity=World and year range(min(birth_years), max(birth_years))
mean_total_population=np.mean(gdp_schooling['Total population (Gapminder, HYDE & UN)'][(gdp_schooling.Entity=='World') & (gdp_schooling.Year>=int(np.min(birth_years))) & (gdp_schooling.Year<=int(np.max(birth_years)))].dropna().astype('int64'))
mean_USA_population, mean_total_population
# Out:
# (104885030.54696132, 2985529619.3939395)

# %%
total_winners=nobel['fullName'].count()

# %%
USA_winners=nobel['fullName'][nobel.birth_countryNow=='USA'].count()

# %%
#P(born in USA | being a winner) = P(being a winner | born in USA) * P (winner) / P(born in USA)

# %%
#P(being a winner | born in USA)== Nobel winners from USA / mean_total_population
P_winner_given_USA = USA_winners/mean_total_population
P_winner_given_USA
# Out:
# 9.177601127120012e-08

# %%
#P (winner)
P_winner=total_winners/mean_total_population
P_winner
# Out:
# 3.091578773843712e-07

# %%
#P(born in USA)
P_born_in_US=mean_USA_population/mean_total_population
P_born_in_US
# Out:
# 0.03513113045860617

# %%
#P(being a winner | born in USA)
P_bornUSA_given_winner= P_winner_given_USA*P_winner/P_born_in_US
P_bornUSA_given_winner
# Out:
# 8.076391641549831e-13
